# %%
import random

# %%
candidati = ['Richelle', 'Milia','Odelia','Calix','Ken','Idina','Olga','Rakan','Lagou','Telfer','Naru','Sol','Paru','Kaion', 'Aruru','Dolucos','Abala','Fiona','LuLu','Aolmond','Galan','Tania','Sander','Babu','Coco','Harfa','Void','Amanda','Zenon','Carmen','Dextor','Ash','Fleta','Ripper','Taros','Solina','Nuel','Ulion','Zagrako','Bazham','Lilith','Benzel','Rare Hero','Normal Hero']
percentuali = [0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.0225,0.0225,0.0225,0.0225,0.0225,0.0225,0.0225,0.0225,36,60]
estrazioni = int(input("quante summons vuoi fare? "))

print (random.choices(population=candidati,weights=percentuali, k=estrazioni))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-d584c78d2149> in <cell line: 3>()
#       1 candidati = ['Richelle', 'Milia','Odelia','Calix','Ken','Idina','Olga','Rakan','Lagou','Telfer','Naru','Sol','Paru','Kaion', 'Aruru','Dolucos','Abala','Fiona','LuLu','Aolmond','Galan','Tania','Sander','Babu','Coco','Harfa','Void','Amanda','Zenon','Carmen','Dextor','Ash','Fleta','Ripper','Taros','Solina','Nuel','Ulion','Zagrako','Bazham','Lilith','Benzel','Rare Hero','Normal Hero']
#       2 percentuali = [0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.1124,0.0225,0.0225,0.0225,0.0225,0.0225,0.0225,0.0225,0.0225,36,60]
# ----> 3 estrazioni = int(input("quante summons vuoi fare? "))
# ...
